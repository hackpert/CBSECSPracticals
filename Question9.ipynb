# %%
from IPython.display import Image #NOT TO BE WRITTEN
Image(filename='/Users/hackpert/Desktop/question9.png') #DO NOT WRITE. QUESTION FOLLOWS

# %%
class Trainer(object):
    def __init__(self,Name,T_ID):
        self.Name = Name
        self.T_ID = T_ID
    def getName(self):
        print self.Name
    def get_ID(self):
        print self.T_ID
class learner(object):
    def __init__(self,name,id):
        self.L_Name = name
        self.L_ID = id
    def getName(self):
        print self.L_Name
    def getLID(self):
        print self.L_ID
class institute(Trainer,learner):
    def __init__(self,name,id):
        self.I_Name = name
        self.I_code = id
    def getName(self):
        print self.I_Name
    def getCode(self):
        print self.I_code

# %%
i = institute(1,2)
